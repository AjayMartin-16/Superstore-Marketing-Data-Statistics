# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_loc = '/content/drive/MyDrive/almabetter/Superstore Marketing Data.xlsx'

# %%
import pandas as pd
df1 = pd.read_excel(file_loc)
df1.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df1.isnull().sum()
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(df1['Income'],bins = 20,kde = True)
plt.show()

# %%
df1.loc[:,'Income'] = df1['Income'].fillna(df1['Income'].median())

# %%
with_hashes = df1['Dt_Customer'].str.contains('#')
with_hashes.sum()
# Out:
# 916

# %% [markdown]
# # Descriptive Statistics of numerical variables

# %%
numerical_cols = [
    'Year_Birth', 'Income', 'MntFishProducts', 'MntMeatProducts', 'MntFruits',
    'MntSweetProducts', 'MntWines', 'MntGoldProds', 'NumDealsPurchases',
    'NumCatalogPurchases', 'NumStorePurchases', 'NumWebPurchases', 'NumWebVisitsMonth', 'Recency'
]

# Calculate basic statistics
stats_summary = df1[numerical_cols].describe().T
stats_summary['variance'] = df1[numerical_cols].var()
stats_summary
# Out:
#                       count          mean           std     min       25%  \
# Year_Birth           2240.0   1968.805804     11.984069  1893.0   1959.00
# Income               2240.0  52237.975446  25037.955891  1730.0  35538.75
# MntFishProducts      2240.0     37.525446     54.628979     0.0      3.00
# MntMeatProducts      2240.0    166.950000    225.715373     0.0     16.00
# MntFruits            2240.0     26.302232     39.773434     0.0      1.00
# MntSweetProducts     2240.0     27.062946     41.280498     0.0      1.00
# MntWines             2240.0    303.935714    336.597393     0.0     23.75
# MntGoldProds         2240.0     44.021875     52.167439     0.0      9.00
# NumDealsPurchases    2240.0      2.325000      1.932238     0.0      1.00
# NumCatalogPurchases  2240.0      2.662054      2.923101     0.0      0.00
# NumStorePurchases    2240.0      5.790179      3.250958     0.0      3.00
# NumWebPurchases      2240.0      4.084821      2.778714     0.0      2.00
# ...

# %% [markdown]
# **Steps taken for handling missing values:**
#
#
# *   Since, Income column has 24 missing values we need to fill that.
# *   For this using histogram visualization will be usefull for analysing whether the data is right skewed or left skewed.
# *   Since it is right skewed, fill with the median is the appropriate choice.

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %%
import pandas as pd
import numpy as np

# List of relevant numerical columns
numerical_cols = [
    'Year_Birth', 'Income', 'MntFishProducts', 'MntMeatProducts', 'MntFruits',
    'MntSweetProducts', 'MntWines', 'MntGoldProds', 'NumDealsPurchases',
    'NumCatalogPurchases', 'NumStorePurchases', 'NumWebPurchases', 'NumWebVisitsMonth', 'Recency'
]

# Compute descriptive statistics
stats_summary1 = df1[numerical_cols].describe().T  # Transpose for better readability

# Calculate IQR and potential outlier thresholds
stats_summary1['IQR'] = stats_summary1['75%'] - stats_summary1['25%']
stats_summary1['Lower Bound'] = stats_summary1['25%'] - 1.5 * stats_summary1['IQR']
stats_summary1['Upper Bound'] = stats_summary1['75%'] + 1.5 * stats_summary1['IQR']
stats_summary1
# Out:
#                       count          mean           std     min       25%  \
# Year_Birth           2240.0   1968.805804     11.984069  1893.0   1959.00
# Income               2240.0  52237.975446  25037.955891  1730.0  35538.75
# MntFishProducts      2240.0     37.525446     54.628979     0.0      3.00
# MntMeatProducts      2240.0    166.950000    225.715373     0.0     16.00
# MntFruits            2240.0     26.302232     39.773434     0.0      1.00
# MntSweetProducts     2240.0     27.062946     41.280498     0.0      1.00
# MntWines             2240.0    303.935714    336.597393     0.0     23.75
# MntGoldProds         2240.0     44.021875     52.167439     0.0      9.00
# NumDealsPurchases    2240.0      2.325000      1.932238     0.0      1.00
# NumCatalogPurchases  2240.0      2.662054      2.923101     0.0      0.00
# NumStorePurchases    2240.0      5.790179      3.250958     0.0      3.00
# NumWebPurchases      2240.0      4.084821      2.778714     0.0      2.00
# ...

# %%
outliers = df1[(df1['Income'] > 117416.25) | (df1['Income'] < -13587.85)]
outliers
# Out:
#          Id  Year_Birth   Education Marital_Status    Income  Kidhome  \
# 325    4931        1977  Graduation       Together  157146.0        0
# 497    1501        1982         PhD        Married  160803.0        0
# 527    9432        1977  Graduation       Together  666666.0        1
# 731    1503        1976         PhD       Together  162397.0        1
# 853    5336        1971      Master       Together  157733.0        1
# 1826   5555        1975  Graduation       Divorced  153924.0        0
# 1925  11181        1949         PhD        Married  156924.0        0
# 2204   8475        1973         PhD        Married  157243.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 325          0   4/29/2013       13         1  ...                2
# 497          0    ########       21        55  ...               17
# 527          0    ########       23         9  ...                8
# ...

# %%
df1['Log_Income'] = np.log1p(df1['Income'])

# %%
sns.histplot(df1['Log_Income'], kde=True,bins=20)
plt.title('Income Distribution After Log Transformation')
plt.show()

# %% [markdown]
# **Steps Taken to handle outliers:**
#
# *   Log transformation can improve linear model performance by stabilizing variance and reducing skewness.

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %%
from scipy.stats import binom

# Assuming `Response` has n=1 trials (single trial binary data)
p = df1['Response'].mean()  # Probability of success
probability = binom.pmf(k=1, n=1, p=p)
print("Probability of success (Response=1):", probability)
# Out:
# Probability of success (Response=1): 0.14910714285714285

# %%
from scipy.stats import norm

mean_income = df1['Income'].mean()
std_income = df1['Income'].std()

# Probability of income between 700000 and 90000
p = norm.cdf(700000, loc=mean_income, scale=std_income) - norm.cdf(90000, loc=mean_income, scale=std_income)
print("Probability of income between 700000 and 90,000:", p)
# Out:
# Probability of income between 700000 and 90,000: 0.06575280039709208

# %%
from scipy.stats import poisson

lambda_visits = df1['NumWebVisitsMonth'].mean()
probability = poisson.pmf(k=8, mu=lambda_visits)  # Probability of 5 visits in a month
print("Probability of exactly 5 web visits in a month:", probability)
# Out:
# Probability of exactly 5 web visits in a month: 0.07772546405853628

# %%
from scipy.stats import shapiro

stat, p = shapiro(df1['Income'])
if p > 0.05:
    print("Income follows a normal distribution.")
else:
    print("Income does not follow a normal distribution.")
# Out:
# Income does not follow a normal distribution.

# %% [markdown]
# **Methods used for calculation:**
#
# *   Finding binomial distribution for Response
# *   Finding normal distribution for income
# *   Finding poission distributioin for number of visits on the webpage
# *   To check whether the income follows normal distribution using shapiro

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

columns_to_analyze = ['Kidhome', 'Teenhome', 'Recency', 'MntWines', 'MntFruits',
                      'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
                      'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
                      'NumCatalogPurchases', 'NumStorePurchases',
                      'NumWebVisitsMonth', 'Response', 'Complain', 'Log_Income']


corr_matrix = df1[columns_to_analyze].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.scatterplot(data=df1, x='Income', y='MntWines')
plt.title('Income vs. Wine Spending')
plt.show()

# %%
sns.boxplot(data=df1, x='Marital_Status', y='MntMeatProducts')
plt.title('Meat Spending by Marital Status')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

features = ['Income', 'MntWines', 'MntMeatProducts', 'NumWebPurchases', 'NumWebVisitsMonth']
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df1[features])

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=4, random_state=42)
df1['Cluster'] = kmeans.fit_predict(df_scaled)

# %%
cluster_summary = df1.groupby('Cluster').mean(numeric_only=True)
print(cluster_summary)
# Out:
#                   Id   Year_Birth        Income   Kidhome  Teenhome  \
# Cluster
# 0        5590.930683  1971.515800  33169.237003  0.801223  0.449541
# 1        5596.397695  1968.648415  80717.474063  0.025937  0.074928
# 2        5446.676083  1965.772128  61267.884181  0.239171  0.785311
# 3        5794.225722  1966.199475  62813.211286  0.191601  0.656168
#
#            Recency    MntWines  MntFruits  MntMeatProducts  MntFishProducts  \
# Cluster
# 0        48.871560   43.116208   5.363914        24.024465         8.208970
# 1        50.634006  663.314121  64.397695       593.922190        96.475504
# 2        48.015066  582.728814  30.954802       173.295669        44.048964
# 3        49.858268  259.632546  39.034121       137.241470        50.228346
#
#          MntSweetProducts  MntGoldProds  NumDealsPurchases  NumWebPurchases  \
# Cluster
# 0                5.226300     16.811417           2.219164         2.201835
# ...

# %% [markdown]
# **High Spenders:**
#
#  Cluster with high income and high spending on luxury products (MntWines, MntGoldProds).
# **Budget-Conscious Shoppers:**
#
# Cluster with low income, high NumDealsPurchases.
#
# **Engaged Online Shoppers:**
#
# Cluster with high NumWebPurchases and frequent NumWebVisitsMonth.
# Actionable Insights:
#
# Tailor marketing campaigns to target high-spending clusters.
# Offer discounts to budget-conscious shoppers to drive loyalty.

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %%
import matplotlib.pyplot as plt
segment_summary = df1.groupby('Cluster').mean(numeric_only = True)[['MntWines', 'MntMeatProducts', 'MntFishProducts']]

segment_summary.plot(kind='bar', figsize=(10, 6), stacked=True)
plt.title('Spending Breakdown by Customer Segment')
plt.ylabel('Average Spending')
plt.xlabel('Segment')
plt.legend(title='Spending Category')
plt.show()

# %%
sns.boxplot(data=df1, x='Cluster', y='NumWebVisitsMonth', palette='Set2')
plt.title('Web Visits by Customer Segment')
plt.xlabel('Segment')
plt.ylabel('Web Visits in Last Month')
plt.show()
# Out:
# <ipython-input-41-878b387deaf0>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df1, x='Cluster', y='NumWebVisitsMonth', palette='Set2')

# %% [markdown]
# **Recommendations:**
#
#
# *   Give offers for married people with less salary
# *   Concentrate on website for purchases
# *   Give some discounts on sweets for less salary people
# *   Ask response from less salary people and average salary people to cover all the audience

# %% [markdown]
# ## Bonus Task - Geogebra Experiment

# %% [markdown]
# Here's the link to an intriguing GeoGebra experiment: [GeoGebra Experiment Link](https://www.geogebra.org/m/LZbwMZtJ)
#
# This experiment lets you simulate coin flips as per your preferences and specifications!
#
# Your task involves recording a video where you'll explain the concept of the **Law of Large Numbers** using this experiment. Dive further into the experience by adjusting the number of coins and exploring varying coin biases. 🪙📹🔍

# %% [markdown]
# Video Link

# %% [markdown]
# https://drive.google.com/file/d/1wXQohfZImlWpPkY_utD8kNSCFnbXL6Tj/view?usp=sharing
